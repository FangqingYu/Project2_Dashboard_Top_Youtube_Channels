# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import pandas as pd
import json
import splinter
import requests

# %%
url = "https://socialblade.com/youtube/top/100/mostviewed"
response = requests.get(url)
soup = bs(response.text, 'lxml')

# %%
names = soup.find_all('a', class_="")
channel_names = [name.text for name in names]

# %%
df = pd.DataFrame(channel_names).rename(columns={0: "Name"}).dropna()
top100_df = df.loc[121:220,:]
top100_df.reset_index(inplace=True, drop=True)
top100_df
# Out:
#                                    Name
# 0                              T-Series
# 1                                   WWE
# 2                             SET India
# 3                       Ryan ToysReview
# 4                            netd müzik
# 5                       Canal KondZilla
# 6                 ABS-CBN Entertainment
# 7            Cocomelon - Nursery Rhymes
# 8                            Movieclips
# 9                             PewDiePie
# 10                    El Reino Infantil
# 11                           Get Movies
# 12  Little Baby Bum - Nursery Rhymes &…
# 13                     JustinBieberVEVO
# 14                       Маша и Медведь
# 15                    WorkpointOfficial
# 16                               Zee TV
# 17                        KatyPerryVEVO
# 18     ChuChu TV Nursery Rhymes & Kids…
# 19                      TaylorSwiftVEVO
# 20                           Ed Sheeran
# 21                          shakiraVEVO
# 22                    Zee Music Company
# 23                         TheEllenShow
# 24                        BuzzFeedVideo
# 25                  GMM GRAMMY OFFICIAL
# 26       FunToys Collector Disney Toys…
# 27                           Wave Music
# 28                               DanTDM
# 29                     Spinnin' Records
# ..                                  ...
# 70                          Ultra Music
# 71                             Eros Now
# 72                             CKN Toys
# 73                                one31
# 74                   قناة طيور الجنة |…
# 75                                As/Is
# 76                          GMA Network
# 77                                  YRF
# 78                 Shemaroo Filmi Gaane
# 79                          BeyoncéVEVO
# 80                     Sony Music India
# 81                                 LEGO
# 82                          JuegaGerman
# 83                          Trap Nation
# 84               Blu Toys Club Surprise
# 85                                  IGN
# 86                             Coldplay
# 87                     OneDirectionVEVO
# 88                          Wiz Khalifa
# 89                 GRAMMY GOLD OFFICIAL
# 90                     Atlantic Records
# 91                   SonyMusicIndiaVEVO
# 92                            Genierock
# 93                     ChainsmokersVEVO
# 94                      DisneyChannelLA
# 95                                Smosh
# 96                      Ultra Bollywood
# 97                        RsiamMusic :…
# 98                            AdeleVEVO
# 99                       ChrisBrownVEVO
#
# [100 rows x 1 columns]

# %%
from config import YouTube_KEY
from datetime import datetime

from apiclient.discovery import build

# %%
youtube = build("youtube", "v3", developerKey=YouTube_KEY)

# %%
top100_df['Channel_ID'] = ""
top100_df['Channel_Description']= ""
#top100_df['Published_Date']= ""
#top100_df['Country']= ""
top100_df['View_Count']= ""
top100_df['Comment_Count'] = ""
top100_df['Subscriber_Count']= ""
top100_df['Video_Counts'] = ""
top100_df['Banner_Image'] = ""
# Out:
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
top100_df.head()
# Out:
#               Name Channel_ID Channel_Description View_Count Comment_Count  \
# 0         T-Series
# 1              WWE
# 2        SET India
# 3  Ryan ToysReview
# 4       netd müzik
#
#   Subscriber_Count Video_Counts Banner_Image
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in top100_df.iterrows():
    
    channel_name = row['Name']
    
    # Get channel ID & Description
    res = youtube.search().list(part='snippet', 
                            q=channel_name,
                            type='channel').execute()
    
    # Get channel ID
    channelID = res['items'][0]['snippet']['channelId']
    
    try:
        top100_df.loc[index, 'Channel_ID'] = channelID
        top100_df.loc[index, 'Channel_Description'] = res['items'][0]['snippet']['description']
    except:
        top100_df.loc[index, 'Channel_ID'] = "NaN"
        top100_df.loc[index, 'Channel_Description'] = "NaN"
        
    
    
    # Get channel country & published date
    #res2 = youtube.channels().list(id=channelID,
                              #part='snippet').execute()
    
    #try:
        #top100_df.loc[index, 'Published_Date'] = res2['items'][0]['snippet']['publishedAt']
        #top100_df.loc[index, 'Country'] = res2['items'][0]['snippet']['country']
    #except:
        #top100_df.loc[index, 'Published_Date'] = "NaN"
        #top100_df.loc[index, 'Country'] = "NaN"
        
    
    
    # Get channel statistics
    res3 = youtube.channels().list(id=channelID,
                              part='statistics').execute()
    
    
    channel_stats = res3['items'][0]['statistics']
  
    try:
        top100_df.loc[index, 'View_Count'] = channel_stats['viewCount']
        top100_df.loc[index, 'Comment_Count'] = channel_stats['commentCount']
        top100_df.loc[index, 'Subscriber_Count'] = channel_stats['subscriberCount']
        top100_df.loc[index, 'Video_Counts'] = channel_stats['videoCount']
    except:
        top100_df.loc[index, 'View_Count'] = "NaN"
        top100_df.loc[index, 'Comment_Count'] = "NaN"
        top100_df.loc[index, 'Subscriber_Count'] = "NaN"
        top100_df.loc[index, 'Video_Counts'] = "NaN"
        
    
    
    
    # Get banner image
    res4 = youtube.channels().list(id=channelID,
                              part="brandingSettings").execute()
    try:
        top100_df.loc[index, 'Banner_Image'] = res4["items"][0]['brandingSettings']['image']['bannerImageUrl']
    except:
        top100_df.loc[index, 'Banner_Image'] = "NaN"
# Out:
# C:\Users\fangq\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-10-c7a6451fc9a1> in <module>()
#       6     res = youtube.search().list(part='snippet',
#       7                             q=channel_name,
# ----> 8                             type='channel').execute()
#       9
#      10     # Get channel ID
#
# ~\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131         return positional_wrapper
#     132
#
# ~\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     849       callback(resp)
#     850     if resp.status >= 300:
# --> 851       raise HttpError(resp, content, uri=self.uri)
#     852     return self.postproc(resp, content)
#     853
#
# HttpError: <HttpError 403 when requesting https://www.googleapis.com/youtube/v3/search?part=snippet&q=Wiz+Khalifa&type=channel&key=AIzaSyBCFgTOhvKA6X3s0sPuVxVR1SucvrFS5tc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
#
# [100 rows x 8 columns]

# %%
# def get_channel_videos(channel_id):
#     '''Take one channel id and return a list of video info 
#      (id, title, description, channel id, channel name) associated with the chanel '''
    
#     # get Uploads playlist id
#     res = youtube.channels().list(id=channel_id, 
#                                   part='contentDetails').execute()
#     playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
#     videos = []
#     next_page_token = None
    
#     while 1:
#         res = youtube.playlistItems().list(playlistId=playlist_id, 
#                                            part='snippet', 
#                                            maxResults=50,
#                                            pageToken=next_page_token).execute()
#         videos += res['items']
#         next_page_token = res.get('nextPageToken')
        
#         if next_page_token is None:
#             break
    
#     return videos

# %%
# def get_videos_stats(video_ids):
#     '''Takes a list of video ids and return a list of dictionaries of video stats'''
#     '''i.e. {'viewCount': '1068581',
#              'likeCount': '15715',
#              'dislikeCount': '1620',
#              'favoriteCount': '0',
#              'commentCount': '600'}'''
#     stats = []
#     for i in range(0, len(video_ids), 50):
#         res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
#                                    part='statistics').execute()
#         stats += [res['items'][0]['statistics']]
        
#     return stats

# %%
# def get_videos_categoryID(video_ids):
#     '''Takes a list of video ids and return a list of video category id'''
#     categoryIDs = []
#     for i in range(0, len(video_ids), 50):
#         res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
#                                    part='snippet').execute()
#         categoryIDs += [res['items'][0]['snippet']['categoryId']]
        
#     return categoryIDs

# %%
# def get_videos_tags(video_ids):
#     '''Takes a list of video ids and return a list of lists of video tags'''
#     tags = []
#     for i in range(0, len(video_ids), 50):
#         res = youtube.videos().list(id=','.join(video_ids[i:i+50]),
#                                    part='snippet').execute()
#         tags += [res['items'][0]['snippet']['tags']]
        
#     return tags

# %%
top100_df["View_Count"] = pd.to_numeric(top100_df["View_Count"])

top100_df = top100_df.sort_values("View_Count", ascending=False).reset_index(drop=True)

top100_df.to_csv("socialblade_top100_byviews.csv")
# Out:
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
top100_df.head()
# Out:
#               Name                Channel_ID  \
# 0         T-Series  UCq-Fj5jknLsUf-MWSy4_brA
# 1              WWE  UCJ5v_MCY6GNUBTO8-D3XoAg
# 2        SET India  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Ryan ToysReview  UChGJGhZ9SOOHvBB0Y4DOO_w
# 4       netd müzik  UCR5wZcXtOUka8jTA57flzMg
#
#                                  Channel_Description    View_Count  \
# 0  "Music can change the world". T-Series is Indi...  6.292300e+10
# 1  WWE on YouTube is your number one spot to catc...  3.024623e+10
# 2  Sony Entertainment Television is a 24 hour Hin...  2.949346e+10
# 3  Ryan loves Toys. Toys Review for kids by a kid...  2.768652e+10
# 4  netd müzik, anlaşmalı müzik yapım firmalarında...  2.762272e+10
#
#   Comment_Count Subscriber_Count Video_Counts  \
# 0             0         86998125        13153
# 1             0         39954727        39820
# 2             0         42508399        29184
# 3             0         18385123         1303
# 4             0         13110387         9545
#
#                                         Banner_Image
# 0  https://yt3.ggpht.com/SdjbnX1Wfr78hO2S-4hwG6jm...
# 1  https://yt3.ggpht.com/IoJHw0dMVwBR4DWb6oelr-9E...
# 2  https://yt3.ggpht.com/G3QDs9kvZGZWGI8SjCLd7w69...
# 3  https://yt3.ggpht.com/2zPMtu7YfcaBMFzszCQZKuH5...
# 4  https://yt3.ggpht.com/xYFclz7MDzGdfDfuToWe4HA8...

# %%
#video_ids =  []
# video_titles = []
# video_descs = []
# dates = []
# channel_ids = []
# channel_names = []

# # Loop through list of top 50 channel IDs
# for channelID in list(top100_df['Channel_ID'])[0:89]:
#     # Request to get all videos associated with this channel ID (returns a list of dictionary)
#     videos = get_channel_videos(channelID)
    
#     # Loop through response
#     for video in videos:
        
#         # Get title for current video
#         try:
#             title = video['snippet']['title']
#         except:
#             title = "NaN"
        
#         video_titles.append(title)
        
#         # Get description for current video
#         try:
#             desc = video['snippet']['description']
            
#         except:
#             desc = "NaN"
            
#         video_descs.append(desc)
        
#         # Get publish date for current video 
#         try:
#             date = video['snippet']['publishedAt']
#         except:
#             date = "NaN"
        
#         dates.append(date)
        
#         # Get channel ID for current video
#         try:
#             channel_id = video['snippet']['channelId']
#         except:
#             channel_id = "NaN"
         
#         channel_ids.append(channel_id)
        
#         # Get channel name for current video
        
#         try:
#             channel_name = video['snippet']['channelTitle']
#         except:
#             channel_name = "NaN"
        
#         channel_names.append(channel_name)
        
         
#         # Get a list of all video IDs (then use it to obtain video stats, category ID and tags)
#         try:
#             video_id = video['snippet']['resourceId']['videoId']
#         except:
#             video_id = "NaN"
       
#         video_ids.append(video_id)

# %%
#print(len(video_ids))
#print(len(video_titles))
#print(len(video_descs))
#print(len(dates))
#print(len(channel_ids))
#print(len(channel_names))

# %%
#top_videos = pd.DataFrame({
    #"Video_ID": video_ids,
    #"Video_Channel_ID": channel_ids,
    #"Video_Channel_Name": channel_names,
    #"Video_Titles": video_titles,
    #"Video_Publish_Date": dates,
    #"Video_Description": video_descs  
#})

#top_videos["Like_Count"] = ""
#top_videos["Dislike_Count"] = ""
#top_videos["Favorite_Count"] = ""
#top_videos["Dislike_Count"] = ""
#top_videos["Comment_Count"] = ""
#top_videos["Category_ID"] = ""
#top_videos["Tags"] = ""

# %%
#top_videos['Video_Channel_Name'].unique()

# %%
base_url = "https://socialblade.com/youtube/channel/"

top100_df["Channel_Type"] = ""
top100_df["Country"] = ""
top100_df['Published_Date'] = ""
top100_df["Daily_Average_Earning"] = ""

# %%
top100_df.head()
# Out:
#               Name                Channel_ID  \
# 0         T-Series  UCq-Fj5jknLsUf-MWSy4_brA
# 1              WWE  UCJ5v_MCY6GNUBTO8-D3XoAg
# 2        SET India  UCpEhnqL0y41EpW2TvWAHD7Q
# 3  Ryan ToysReview  UChGJGhZ9SOOHvBB0Y4DOO_w
# 4       netd müzik  UCR5wZcXtOUka8jTA57flzMg
#
#                                  Channel_Description    View_Count  \
# 0  "Music can change the world". T-Series is Indi...  6.292300e+10
# 1  WWE on YouTube is your number one spot to catc...  3.024623e+10
# 2  Sony Entertainment Television is a 24 hour Hin...  2.949346e+10
# 3  Ryan loves Toys. Toys Review for kids by a kid...  2.768652e+10
# 4  netd müzik, anlaşmalı müzik yapım firmalarında...  2.762272e+10
#
#   Comment_Count Subscriber_Count Video_Counts  \
# 0             0         86998125        13153
# 1             0         39954727        39820
# 2             0         42508399        29184
# 3             0         18385123         1303
# 4             0         13110387         9545
#
#                                         Banner_Image Channel_Type Country  \
# 0  https://yt3.ggpht.com/SdjbnX1Wfr78hO2S-4hwG6jm...
# 1  https://yt3.ggpht.com/IoJHw0dMVwBR4DWb6oelr-9E...
# 2  https://yt3.ggpht.com/G3QDs9kvZGZWGI8SjCLd7w69...
# 3  https://yt3.ggpht.com/2zPMtu7YfcaBMFzszCQZKuH5...
# 4  https://yt3.ggpht.com/xYFclz7MDzGdfDfuToWe4HA8...
#
#   Published_Date Daily_Average_Earning
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in top100_df.iterrows():
    
    url = base_url + row["Channel_ID"]
    
    response = requests.get(url)
    soup = bs(response.text, 'lxml')
    
    try:
        channel_type = soup.find("a",id="youtube-user-page-channeltype").text
    except:
        channel_type = "NaN"
    
    top100_df.loc[index, "Channel_Type"] = channel_type
    
    
    try:
        country = soup.find("span", id="youtube-stats-header-country").text
    except:
        country = "NaN"
        
    top100_df.loc[index, "Country"] = country
        
    
    try:
        date = soup.find_all("div",  class_="YouTubeUserTopInfo")[len(soup.find_all("div",  class_="YouTubeUserTopInfo"))-1].\
                    find("span",style="font-weight: bold;").text
    except:
        date = "NaN"
    
    top100_df.loc[index, 'Published_Date'] = date
        
    
    
    try:
        link = soup.find("a", style="text-decoration: none;").get('href')
        start = link.find("(")+1
        end = link.find(")")
        earning = link[start:end]
    except:
        earning = "NaN"
    
    top100_df.loc[index, "Daily_Average_Earning"] = earning
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     355             server_hostname=hostname,
# --> 356             ssl_context=context)
#     357
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     358         if HAS_SNI and server_hostname is not None:
# --> 359             return context.wrap_socket(sock, server_hostname=server_hostname)
#     360
#
# ~\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# ~\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     849                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 850                     self.do_handshake()
#     851             except (OSError, ValueError):
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1107                 self.settimeout(None)
# -> 1108             self._sslobj.do_handshake()
#    1109         finally:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~\Anaconda3\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     848         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 849             conn.connect()
#     850
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     355             server_hostname=hostname,
# --> 356             ssl_context=context)
#     357
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     358         if HAS_SNI and server_hostname is not None:
# --> 359             return context.wrap_socket(sock, server_hostname=server_hostname)
#     360
#
# ~\Anaconda3\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# ~\Anaconda3\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     849                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 850                     self.do_handshake()
#     851             except (OSError, ValueError):
#
# ~\Anaconda3\lib\ssl.py in do_handshake(self, block)
#    1107                 self.settimeout(None)
# -> 1108             self._sslobj.do_handshake()
#    1109         finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-34-b3f8049ee238> in <module>()
#       3     url = base_url + row["Channel_ID"]
#       4
# ----> 5     response = requests.get(url)
#       6     soup = bs(response.text, 'lxml')
#       7
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     493
#     494         except (ProtocolError, socket.error) as err:
# --> 495             raise ConnectionError(err, request=request)
#     496
#     497         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %%
url = "https://socialblade.com/youtube/channel/UCffDXn7ycAzwL2LDlbyWOTw"
response = requests.get(url)
soup = bs(response.text, 'lxml')

# %%
channel_type = soup.find("a",id="youtube-user-page-channeltype").text
country = soup.find("span", id="youtube-stats-header-country").text
date = soup.find_all("div",  class_="YouTubeUserTopInfo")[len(soup.find_all("div",  class_="YouTubeUserTopInfo"))-1].\
find("span",style="font-weight: bold;").text
print(channel_type)
print(country)
print(date)
# Out:
# Music
# BR
# Mar 21st, 2012

# %%
top100_df
# Out:
#                                    Name                Channel_ID  \
# 0                              T-Series  UCq-Fj5jknLsUf-MWSy4_brA
# 1                                   WWE  UCJ5v_MCY6GNUBTO8-D3XoAg
# 2                             SET India  UCpEhnqL0y41EpW2TvWAHD7Q
# 3                       Ryan ToysReview  UChGJGhZ9SOOHvBB0Y4DOO_w
# 4                            netd müzik  UCR5wZcXtOUka8jTA57flzMg
# 5                       Canal KondZilla  UCffDXn7ycAzwL2LDlbyWOTw
# 6                 ABS-CBN Entertainment  UCstEtN0pgOmCf02EdXsGChw
# 7            Cocomelon - Nursery Rhymes  UCbCmjCuTUZos6Inko4u57UQ
# 8                            Movieclips  UC3gNmTGu-TTbFPpfSs5kNkg
# 9                             PewDiePie  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 10                    El Reino Infantil  UCK1i2UviaXLUNrZlAFpw_jA
# 11                           Get Movies  UClZkHt2kNIgyrTTPnSQV3SA
# 12  Little Baby Bum - Nursery Rhymes &…  UCKAqou7V9FAWXpZd9xtOg3Q
# 13                     JustinBieberVEVO  UCHkj014U2CQ2Nv0UZeYpE_A
# 14                       Маша и Медведь  UCRv76wLBC73jiP7LX4C3l8Q
# 15                    WorkpointOfficial  UC3ZkCd7XtUREnjjt3cyY_gg
# 16                               Zee TV  UCppHT7SZKKvar4Oc9J4oljQ
# 17                        KatyPerryVEVO  UC-8Q-hLdECwQmaWNwXitYDw
# 18     ChuChu TV Nursery Rhymes & Kids…  UCBnZ16ahKA2DZ_T5W0FPUXg
# 19                      TaylorSwiftVEVO  UCANLZYMidaCbLQFWXBC95Jg
# 20                          shakiraVEVO  UCGnjeahCJW1AF34HBmQTJ-Q
# 21                    Zee Music Company  UCFFbwnve3yF62-tVXkTyHqg
# 22                         TheEllenShow  UCp0hYYBW6IMayGgR-WeoCvQ
# 23                        BuzzFeedVideo  UCpko_-a4wgz2u_DgDgd9fqA
# 24                  GMM GRAMMY OFFICIAL  UCG9gfnA5UDoLvz-tC9B-HKw
# 25       FunToys Collector Disney Toys…  UCqdGW_m8Rim4FeMM29keDEg
# 26                               DanTDM  UCS5Oz6CHmeoF7vSad0qqXfw
# 15   Nov 5th, 2012    $4.2K - $67.8K per day
# 16  Dec 11th, 2005   $7.3K - $116.1K per day
# 17  Dec 13th, 2009    $1.4K - $22.4K per day
# 18   Feb 9th, 2013      $2K - $32.7K per day
# 19  May 12th, 2009    $1.1K - $17.1K per day
# 20   Sep 2nd, 2009    $1.3K - $20.3K per day
# 21  Mar 12th, 2014    $5.7K - $91.6K per day
# 22  Nov 21st, 2006    $2.4K - $38.7K per day
# 23  Aug 10th, 2011      $1K - $16.3K per day
# 24   Nov 8th, 2010    $1.8K - $28.2K per day
# 25  Apr 13th, 2011      $518 - $8.3K per day
# 26  Jul 14th, 2012    $1.3K - $20.3K per day
# 27  Jul 12th, 2007    $1.4K - $22.1K per day
# 28   Aug 4th, 2007   $6.8K - $109.3K per day
# 29  May 12th, 2009     $934 - $14.9K per day
# ..             ...                       ...
# 70   Apr 9th, 2013      $515 - $8.2K per day
# 71  Nov 20th, 2006    $3.3K - $53.2K per day
# 72   Jun 7th, 2006      $3K - $47.2K per day
# 73  Jun 11th, 2010    $4.1K - $65.9K per day
# 74   Sep 2nd, 2009     $865 - $13.8K per day
# 75   Sep 2nd, 2009    $2.6K - $42.2K per day
# 76  Oct 22nd, 2005    $1.1K - $16.9K per day
# 77  May 19th, 2013    $1.4K - $22.9K per day
# 78  Sep 23rd, 2012      $1.4K - $23K per day
# 79  Dec 23rd, 2010      $255 - $4.1K per day
# 80  Sep 19th, 2006      $1K - $16.7K per day
# 81   Dec 4th, 2010      $466 - $7.5K per day
# 82  Dec 20th, 2011      $318 - $5.1K per day
# 83  Dec 20th, 2013      $235 - $3.8K per day
# 84  May 21st, 2013       $84 - $1.3K per day
# 85   Jul 3rd, 2013       $82 - $1.3K per day
# 86  Jun 13th, 2013       $72 - $1.1K per day
# 87  Jun 12th, 2013        $39 - $617 per day
# 88             NaN                       NaN
# 89             NaN                       NaN
# 90             NaN                       NaN
# 91             NaN                       NaN
# 92             NaN                       NaN
# 93             NaN                       NaN
# 94             NaN                       NaN
# 95             NaN                       NaN
# 96             NaN                       NaN
# 97             NaN                       NaN
# 98             NaN                       NaN
# 99             NaN                       NaN
#
# [100 rows x 12 columns]

# %%
top83_df = top100_df[:83]
top83_df['View_Count'] = pd.to_numeric(top86_df['View_Count'])
top83_df = top86_df.sort_values("View_Count", ascending=False)
top83_df
# Out:
# C:\Users\fangq\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    Name                Channel_ID  \
# 0                              T-Series  UCq-Fj5jknLsUf-MWSy4_brA
# 1                                   WWE  UCJ5v_MCY6GNUBTO8-D3XoAg
# 2                             SET India  UCpEhnqL0y41EpW2TvWAHD7Q
# 3                       Ryan ToysReview  UChGJGhZ9SOOHvBB0Y4DOO_w
# 4                            netd müzik  UCR5wZcXtOUka8jTA57flzMg
# 5                       Canal KondZilla  UCffDXn7ycAzwL2LDlbyWOTw
# 6                 ABS-CBN Entertainment  UCstEtN0pgOmCf02EdXsGChw
# 7            Cocomelon - Nursery Rhymes  UCbCmjCuTUZos6Inko4u57UQ
# 72                     3000.0                    25100.0
# 73                     4100.0                    35000.0
# 74                    13800.0                   439400.0
# 75                     2600.0                    22400.0
# 76                     1100.0                     9000.0
# 77                     1400.0                    12150.0
# 78                     1400.0                    12200.0
# 79                     4100.0                   129550.0
# 80                     1000.0                     8850.0
# 81                     7500.0                   236750.0
# 82                     5100.0                   161550.0
#
# [83 rows x 15 columns]

# %%
import re
import numpy

# %%
# Clean Daily_Average Earning
 
new_earning = []
# Use real expression to extract integers and decimals
# and store in new_earning
for index, row in top86_df.iterrows():
    new_earning.append(re.findall("[-+]?[.]?[\d]+(?:,\d\d\d)*[\.]?\d*(?:[eE][-+]?\d+)?", row["Daily_Average_Earning"]))
    
new_earning2 = []
# times each number by 1000 and store in new_earning2
for items in new_earning:
    items = [float(i)*1000 for i in items]
    new_earning2.append(items)
        
# Take average and store in average_earning
average_earning = [numpy.average([n[1],n[0]]) for n in new_earning2]
#average_earning

# High earning
earning_low = [numpy.min(n) for n in new_earning2]
# Low earning
earning_hi = [numpy.max(n) for n in new_earning2]

# %%
top83_df['Daily_Average_Earning_High'] = earning_hi
top83_df['Daily_Average_Earning_Low'] = earning_low
top83_df['Daily_Average_Earning_Mid'] = average_earning

# %%
top83_df
# Out:
#                                    Name                Channel_ID  \
# 0                              T-Series  UCq-Fj5jknLsUf-MWSy4_brA
# 1                                   WWE  UCJ5v_MCY6GNUBTO8-D3XoAg
# 2                             SET India  UCpEhnqL0y41EpW2TvWAHD7Q
# 3                       Ryan ToysReview  UChGJGhZ9SOOHvBB0Y4DOO_w
# 4                            netd müzik  UCR5wZcXtOUka8jTA57flzMg
# 5                       Canal KondZilla  UCffDXn7ycAzwL2LDlbyWOTw
# 6                 ABS-CBN Entertainment  UCstEtN0pgOmCf02EdXsGChw
# 7            Cocomelon - Nursery Rhymes  UCbCmjCuTUZos6Inko4u57UQ
# 8                            Movieclips  UC3gNmTGu-TTbFPpfSs5kNkg
# 9                             PewDiePie  UC-lHJZR3Gqxm24_Vd_AJ5Yw
# 10                    El Reino Infantil  UCK1i2UviaXLUNrZlAFpw_jA
# 11                           Get Movies  UClZkHt2kNIgyrTTPnSQV3SA
# 12  Little Baby Bum - Nursery Rhymes &…  UCKAqou7V9FAWXpZd9xtOg3Q
# 13                     JustinBieberVEVO  UCHkj014U2CQ2Nv0UZeYpE_A
# 14                       Маша и Медведь  UCRv76wLBC73jiP7LX4C3l8Q
# 15                    WorkpointOfficial  UC3ZkCd7XtUREnjjt3cyY_gg
# 16                               Zee TV  UCppHT7SZKKvar4Oc9J4oljQ
# 17                        KatyPerryVEVO  UC-8Q-hLdECwQmaWNwXitYDw
# 18     ChuChu TV Nursery Rhymes & Kids…  UCBnZ16ahKA2DZ_T5W0FPUXg
# 19                      TaylorSwiftVEVO  UCANLZYMidaCbLQFWXBC95Jg
# 20                          shakiraVEVO  UCGnjeahCJW1AF34HBmQTJ-Q
# 21                    Zee Music Company  UCFFbwnve3yF62-tVXkTyHqg
# 22                         TheEllenShow  UCp0hYYBW6IMayGgR-WeoCvQ
# 79  Dec 23rd, 2010      $255 - $4.1K per day                    255000.0
# 80  Sep 19th, 2006      $1K - $16.7K per day                     16700.0
# 81   Dec 4th, 2010      $466 - $7.5K per day                    466000.0
# 82  Dec 20th, 2011      $318 - $5.1K per day                    318000.0
#
#     Daily_Average_Earning_Low  Daily_Average_Earning_Mid
# 0                     23900.0                   203500.0
# 1                      5000.0                    42850.0
# 2                     12200.0                   103550.0
# 3                      5400.0                    46250.0
# 4                      5200.0                    44350.0
# 5                      4900.0                    41700.0
# 6                      6600.0                    56250.0
# 7                     21600.0                   183850.0
# 8                      6100.0                    52150.0
# 9                      2900.0                    24650.0
# 10                     4700.0                    39850.0
# 11                     3000.0                    25400.0
# 12                     1700.0                    14500.0
# 13                    13400.0                   426200.0
# 14                     3800.0                    32100.0
# 15                     4200.0                    36000.0
# 16                     7300.0                    61700.0
# 17                     1400.0                    11900.0
# 18                     2000.0                    17350.0
# 19                     1100.0                     9100.0
# 20                     1300.0                    10800.0
# 21                     5700.0                    48650.0
# 22                     2400.0                    20550.0
# 23                     1000.0                     8650.0
# 24                     1800.0                    15000.0
# 25                     8300.0                   263150.0
# 26                     1300.0                    10800.0
# 27                     1400.0                    11750.0
# 28                     6800.0                    58050.0
# 29                    14900.0                   474450.0
# ..                        ...                        ...
# 53                     2200.0                    18550.0
# 54                     1200.0                    10350.0
# 55                     1100.0                     9500.0
# 56                    15800.0                   502400.0
# 57                     3700.0                    31450.0
# 58                     1500.0                    12550.0
# 59                     2300.0                    19600.0
# 60                    12600.0                   398800.0
# 61                     7800.0                    66250.0
# 62                     3500.0                    29750.0
# 63                     2600.0                    22350.0
# 64                     1100.0                     9000.0
# 65                     1200.0                    10400.0
# 66                     2000.0                    17100.0
# 67                     3900.0                    32800.0
# 68                     4100.0                    35150.0
# 69                     2800.0                    23450.0
# 70                     8200.0                   261600.0
# 71                     3300.0                    28250.0
# 72                     3000.0                    25100.0
# 73                     4100.0                    35000.0
# 74                    13800.0                   439400.0
# 75                     2600.0                    22400.0
# 76                     1100.0                     9000.0
# 77                     1400.0                    12150.0
# 78                     1400.0                    12200.0
# 79                     4100.0                   129550.0
# 80                     1000.0                     8850.0
# 81                     7500.0                   236750.0
# 82                     5100.0                   161550.0
#
# [83 rows x 15 columns]

# %%
top83_df['Channel_Type'].value_counts()
# Out:
# Music            35
# Entertainment    24
# Games             9
# Education         5
# People            3
# Film              3
# Comedy            2
# Howto             1
# Sports            1
# Name: Channel_Type, dtype: int64

# %%
top83_df['Country'].value_counts()
# Out:
# US    39
# IN    13
# CA     4
# TH     4
# BR     3
# RU     2
# KR     2
# PH     2
# GB     2
# CO     1
# ES     1
# AU     1
# IE     1
# JO     1
# PR     1
# TR     1
# MX     1
# NL     1
# AR     1
# FR     1
# CL     1
# Name: Country, dtype: int64

# %%
import sqlite3
conn = sqlite3.connect('YouTube_Viz.sqlite')

# Import SQL Alchemy
from sqlalchemy import create_engine

# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float

# %%
# Create Channel and Video classes
# ----------------------------------
class Channel(Base):
    __tablename__ = 'channel'
    id = Column(Integer, primary_key=True)
    Channel_ID = Column(String(50))
    Channel_Type =  Column(String(20))
    Name = Column(String(255))
    Channel_Description = Column(String(255))
    Published_Date = Column(String(255))
    Country = Column(String(10))
    View_Count = Column(Integer)
    Comment_Count = Column(String(255))
    Subscriber_Count = Column(Integer)
    Video_Count = Column(Integer)
    Banner_Image = Column(String(800))
    Daily_Average_Earning = Column(String(255))
    Daily_Average_Earning_High = Column(Float)
    Daily_Average_Earning_Low = Column(Float)
    Daily_Average_Earning_Mid = Column(Float)

# %%
# Create Database Connection
# ----------------------------------
engine = create_engine("sqlite:///YouTube_Top_Channels.sqlite")
conn = engine.connect()

# %%
# Create both the Surfer and Board tables within the database
Base.metadata.create_all(conn)

# %%
# To push the objects made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
top83_df.columns
# Out:
# Index(['Name', 'Channel_ID', 'Channel_Description', 'View_Count',
#        'Comment_Count', 'Subscriber_Count', 'Video_Counts', 'Banner_Image',
#        'Channel_Type', 'Country', 'Published_Date', 'Daily_Average_Earning',
#        'Daily_Average_Earning_High', 'Daily_Average_Earning_Low',
#        'Daily_Average_Earning_Mid'],
#       dtype='object')

# %%
# create a loop for channels and add to DB 
for index, row in top83_df.iterrows():
    name = row['Name']
    channel_id = row['Channel_ID']
    channel_type = row['Channel_Type']
    date = row['Published_Date']
    desc = row['Channel_Description']
    view = row['View_Count']
    comment = row['Comment_Count']
    sub = row['Subscriber_Count']
    vid = row['Video_Counts']
    banner = row['Banner_Image']
    country = row['Country']
    earning = row['Daily_Average_Earning']
    earning_hi = row['Daily_Average_Earning_High']
    earning_low = row['Daily_Average_Earning_Low']
    earning_mid = row['Daily_Average_Earning_Mid']
    
    channel = Channel(Channel_ID = channel_id,
                      Channel_Type =  channel_type,
                      Name = name,
                      Channel_Description = desc,
                      Published_Date = date,
                      Country = country,
                      View_Count = view,
                      Comment_Count = comment,
                      Subscriber_Count = sub,
                      Video_Count = vid,
                      Banner_Image = banner,
                      Daily_Average_Earning = earning,
                      Daily_Average_Earning_High = earning_hi,
                      Daily_Average_Earning_Low = earning_low,
                      Daily_Average_Earning_Mid = earning_mid
                     )
    session.add(channel)

# %%
#Commit all objects to the database    
session.commit()

# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import inspect

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['channel']

# %%
inspector = inspect(engine)

for item in inspector.get_columns('channel'):
    print(item['name'], item['type'])
# Out:
# id INTEGER
# Channel_ID VARCHAR(50)
# Channel_Type VARCHAR(20)
# Name VARCHAR(255)
# Channel_Description VARCHAR(255)
# Published_Date VARCHAR(255)
# Country VARCHAR(10)
# View_Count INTEGER
# Comment_Count VARCHAR(255)
# Subscriber_Count INTEGER
# Video_Count INTEGER
# Banner_Image VARCHAR(800)
# Daily_Average_Earning FLOAT
# Daily_Average_Earning_High FLOAT
# Daily_Average_Earning_Low FLOAT
# Daily_Average_Earning_Mid FLOAT

# %%
# Query the database and collect all of the surfers in the Surfer table
channel_list = session.query(Channel)

for channel in channel_list:
    print(channel.Name)
    print(channel.Published_Date)
    print(channel.View_Count)
    print(channel.Channel_ID)
    print(channel.Country)
    print(channel.Daily_Average_Earning)
# Out:
# T-Series
# Mar 13th, 2006
# 62923002389
# UCq-Fj5jknLsUf-MWSy4_brA
# IN
# $23.9K - $383.1K per day
# WWE
# May 11th, 2007
# 30246226656
# UCJ5v_MCY6GNUBTO8-D3XoAg
# US
# $5K - $80.7K per day
# SET India
# Sep 20th, 2006
# 29493459610
# UCpEhnqL0y41EpW2TvWAHD7Q
# IN
# $12.2K - $194.9K per day
# Ryan ToysReview
# Mar 17th, 2015
# 27686524413
# UChGJGhZ9SOOHvBB0Y4DOO_w
# US
# $5.4K - $87.1K per day
# netd müzik
# Jan 23rd, 2014
# 27622717527
# UCR5wZcXtOUka8jTA57flzMg
# TR
# $5.2K - $83.5K per day
# Canal KondZilla
# Mar 21st, 2012
# 23258379454
# UCffDXn7ycAzwL2LDlbyWOTw
# BR
# $4.9K - $78.5K per day
# ABS-CBN Entertainment
# Jul 16th, 2008
# 21701207455
# UCstEtN0pgOmCf02EdXsGChw
# PH
# $6.6K - $105.9K per day
# Cocomelon - Nursery Rhymes
# Sep 1st, 2006
# 21031876537
# UCbCmjCuTUZos6Inko4u57UQ
# US
# $21.6K - $346.1K per day
# Movieclips
# Apr 28th, 2006
# 20944787757
# UC3gNmTGu-TTbFPpfSs5kNkg
# US
# $6.1K - $98.2K per day
# PewDiePie
# Apr 29th, 2010
# 20555595375
# UC-lHJZR3Gqxm24_Vd_AJ5Yw
# US
# $2.9K - $46.4K per day
# El Reino Infantil
# Jun 2nd, 2011
# 19112663055
# UCK1i2UviaXLUNrZlAFpw_jA
# AR
# $4.7K - $75K per day
# Get Movies
# Dec 16th, 2006
# 18918169220
# UClZkHt2kNIgyrTTPnSQV3SA
# RU
# $3K - $47.8K per day
# Little Baby Bum - Nursery Rhymes &…
# Jun 22nd, 2011
# 18517296127
# UCKAqou7V9FAWXpZd9xtOg3Q
# US
# $1.7K - $27.3K per day
# JustinBieberVEVO
# Sep 26th, 2009
# 18439633105
# UCHkj014U2CQ2Nv0UZeYpE_A
# US
# $839 - $13.4K per day
# Маша и Медведь
# May 31st, 2011
# 18390593192
# UCRv76wLBC73jiP7LX4C3l8Q
# RU
# $3.8K - $60.4K per day
# WorkpointOfficial
# Nov 5th, 2012
# 17276768137
# UC3ZkCd7XtUREnjjt3cyY_gg
# TH
# $4.2K - $67.8K per day
# Zee TV
# Dec 11th, 2005
# 17250253809
# UCppHT7SZKKvar4Oc9J4oljQ
# IN
# $7.3K - $116.1K per day
# KatyPerryVEVO
# Dec 13th, 2009
# 17009715727
# UC-8Q-hLdECwQmaWNwXitYDw
# US
# $1.4K - $22.4K per day
# ChuChu TV Nursery Rhymes & Kids…
# Feb 9th, 2013
# 16695500110
# UCBnZ16ahKA2DZ_T5W0FPUXg
# IN
# $2K - $32.7K per day
# TaylorSwiftVEVO
# May 12th, 2009
# 16243367871
# UCANLZYMidaCbLQFWXBC95Jg
# US
# $1.1K - $17.1K per day
# shakiraVEVO
# Sep 2nd, 2009
# 15583976492
# UCGnjeahCJW1AF34HBmQTJ-Q
# US
# $1.3K - $20.3K per day
# Zee Music Company
# Mar 12th, 2014
# 15064151941
# UCFFbwnve3yF62-tVXkTyHqg
# IN
# $5.7K - $91.6K per day
# TheEllenShow
# Nov 21st, 2006
# 15042263417
# UCp0hYYBW6IMayGgR-WeoCvQ
# US
# $2.4K - $38.7K per day
# BuzzFeedVideo
# Aug 10th, 2011
# 14828637804
# UCpko_-a4wgz2u_DgDgd9fqA
# US
# $1K - $16.3K per day
# GMM GRAMMY OFFICIAL
# Nov 8th, 2010
# 14766384941
# UCG9gfnA5UDoLvz-tC9B-HKw
# TH
# $1.8K - $28.2K per day
# FunToys Collector Disney Toys…
# Apr 13th, 2011
# 14553333081
# UCqdGW_m8Rim4FeMM29keDEg
# US
# $518 - $8.3K per day
# DanTDM
# Jul 14th, 2012
# 14386683457
# UCS5Oz6CHmeoF7vSad0qqXfw
# GB
# $1.3K - $20.3K per day
# Spinnin' Records
# Jul 12th, 2007
# 14282244647
# UCpDJl2EmP7Oh90Vylx0dZtA
# NL
# $1.4K - $22.1K per day
# SAB TV
# Aug 4th, 2007
# 13829599510
# UC6-F5tO8uklgE9Zy8IvbdFw
# IN
# $6.8K - $109.3K per day
# RihannaVEVO
# May 12th, 2009
# 13689923585
# UC2xskkQVFEpLcGFnNSLQY0A
# US
# $934 - $14.9K per day
# WORLDSTARHIPHOP
# Nov 8th, 2008
# 13676373145
# UC-yXuc1__OzjwpsJPlxYUCQ
# US
# $3.4K - $54.7K per day
# [토이푸딩] ToyPudding TV
# May 13th, 2014
# 13416111500
# UCKqx9r4mrFglauNBJc1L_eg
# US
# $2.2K - $35.7K per day
# SMTOWN
# Mar 18th, 2006
# 13347428718
# UCEf_Bc-KVd7onSeifS3py9g
# KR
# $2.1K - $33.6K per day
# EminemVEVO
# May 12th, 2009
# 12670260378
# UC20vb-R_px4CguHzzBPhoyQ
# US
# $1.5K - $24.7K per day
# PopularMMOs
# Apr 17th, 2012
# 12613552149
# UCpGdL9Sn3Q5YWUH2DVUW1Ug
# US
# $922 - $14.8K per day
# Super Simple Songs - Kids Songs
# Sep 8th, 2006
# 12452569863
# UCLsooMJoIpl_7ux2jvdPB-Q
# CA
# $3.5K - $55.3K per day
# 5-Minute Crafts
# Nov 15th, 2016
# 12427624755
# UC295-Dw_tDNtZXFeAPAW6Aw
# US
# $4.8K - $77.3K per day
# 1theK (원더케이)
# Jan 31st, 2011
# 12405741352
# UCweOkPb1wVVH0Q0Tlj4a5Pw
# KR
# $2.7K - $44K per day
# Maroon5VEVO
# May 12th, 2009
# 12206052946
# UCN1hnUccO4FD5WfM7ithXaw
# US
# $2.4K - $39.2K per day
# WatchMojo.com
# Jan 25th, 2007
# 12007561965
# UCaWd5_7JhbQBe4dknZhsHJg
# CA
# $1.2K - $18.7K per day
# EnriqueIglesiasVEVO
# May 12th, 2009
# 11861999603
# UCVttQE6tS_agDSAU61Q65aA
# US
# $804 - $12.9K per day
# Family Fun Pack
# Oct 3rd, 2011
# 11488565071
# UCvthuVsurPaVz2a7_4LepGg
# US
# $886 - $14.2K per day
# Baby Big Mouth
# Mar 5th, 2013
# 11306498971
# UCWr4vlkj5xXQ4bSXNeTT2AA
# CA
# $1.1K - $16.9K per day
# Ch3Thailand
# May 29th, 2014
# 11293034959
# UC48h7Dst_hX82HxOf3xJw_w
# TH
# $1.4K - $21.7K per day
# jbalvinVEVO
# Sep 30th, 2010
# 11286450032
# UCrHL_BF5lHyK43BxLU8-vBQ
# CO
# $1.3K - $20K per day
# CVS 3D Rhymes
# Aug 26th, 2008
# 11208645602
# UCsPF3cApzCohxPp5oKdoWSQ
# IN
# $2.2K - $34.8K per day
# NickyJamTV
# Jan 10th, 2012
# 11108585115
# UCpb_iJuhFe8V6rQdbNqfAlQ
# PR
# $1K - $16.1K per day
# ArianaGrandeVevo
# Oct 21st, 2010
# 11054202408
# UC0VOyT2OCBKdQhF3BAbZ-1g
# US
# $3.9K - $62K per day
# Colors TV
# Jun 13th, 2008
# 10943558006
# UC55IWqFLDH1Xp7iu1_xknRA
# IN
# $3.6K - $58K per day
# Galinha Pintadinha
# Aug 30th, 2006
# 10941298542
# UCBAb_DK4GYZqZR9MFA7y2Xg
# BR
# $2.2K - $35K per day
# MalumaVEVO
# Jun 15th, 2011
# 10807537931
# UCFkoPRmuxqr37jvGmmpzhzQ
# US
# $800 - $12.8K per day
# The Tonight Show Starring Jimmy…
# Jan 8th, 2006
# 10759425275
# UC8-Th83bH_thdKZDJCrn88g
# US
# $1.7K - $27.9K per day
# Markiplier
# May 26th, 2012
# 10758813557
# UC7_YxT-KID8kRbqZo7MyscQ
# US
# $1.1K - $17.7K per day
# CookieSwirlC
# Nov 3rd, 2013
# 10737890437
# UCelMeixAOTs2OQAAi9wU8-g
# US
# $2.2K - $34.9K per day
# Fueled By Ramen
# Jun 9th, 2006
# 10735392406
# UClVrJwcIy7saPcGc1nct80A
# US
# $1.2K - $19.5K per day
# jacksepticeye
# Feb 24th, 2007
# 10701556106
# UCYzPXprvl5Y-Sf0g4vX-m6g
# IE
# $1.1K - $17.9K per day
# VanossGaming
# Sep 15th, 2011
# 10569359953
# UCKqH_9mk1waLgBiL2vT5b9g
# CA
# $989 - $15.8K per day
# Speed Records
# Nov 22nd, 2012
# 10376140749
# UCOsyDsO5tIt-VZ1iwjdQmew
# IN
# $3.7K - $59.2K per day
# CalvinHarrisVEVO
# Oct 15th, 2009
# 10364856115
# UCaHNFIob5Ixv74f5on3lvIw
# US
# $1.5K - $23.6K per day
# LuisFonsiVEVO
# May 12th, 2009
# 10361622549
# UCLp8RBhQHu9wSsq62j_Md6A
# US
# $2.3K - $36.9K per day
# Movieclips Trailers
# Apr 1st, 2011
# 10325307026
# UCi8e0iOVk1fEOogdfu4YgfA
# US
# $785 - $12.6K per day
# Badabun
# Oct 14th, 2014
# 10312081951
# UCYWOjHweP2V-8kGKmmAmQJQ
# MX
# $7.8K - $124.7K per day
# GR6 EXPLODE
# Aug 5th, 2014
# 10114086393
# UCNUQK9mQoqi4yNXw2_Rj6SA
# BR
# $3.5K - $56K per day
# FGTeeV
# May 24th, 2013
# 10089186654
# UCC-RHF_77zQdKcA75hr5oTQ
# US
# $2.6K - $42.1K per day
# VEGETTA777
# Mar 2nd, 2008
# 10083928473
# UCam8T03EOFBsNdR0thrFHdQ
# ES
# $1.1K - $16.9K per day
# Ultra Music
# Oct 24th, 2006
# 10064801858
# UC4rasfm9J-X4jNl9SvXp8xA
# US
# $1.2K - $19.6K per day
# Eros Now
# Feb 27th, 2007
# 10015780433
# UCX52tYZiEh_mHoFja3Veciw
# IN
# $2K - $32.2K per day
# CKN Toys
# Mar 28th, 2015
# 9961706286
# UCfaZw8XH_zmAVkBst_MPD6w
# AU
# $3.9K - $61.7K per day
# one31
# Jan 10th, 2013
# 9908551252
# UC8f7MkX4MFOOJ2SerXLInCA
# TH
# $4.1K - $66.2K per day
# قناة طيور الجنة |…
# Nov 24th, 2008
# 9823185186
# UCozAuGJZ5MPoijz8IE_1Gtw
# JO
# $2.8K - $44.1K per day
# As/Is
# Apr 9th, 2013
# 9717889112
# UCay_OLhWtf9iklq8zg_or0g
# US
# $515 - $8.2K per day
# GMA Network
# Nov 20th, 2006
# 9581781042
# UCKL5hAuzgFQsyrsQKgU0Qng
# PH
# $3.3K - $53.2K per day
# YRF
# Jun 7th, 2006
# 9546412001
# UCbTLwN10NoCU4WDzLf1JMOA
# IN
# $3K - $47.2K per day
# Shemaroo Filmi Gaane
# Jun 11th, 2010
# 9445697702
# UCP6uH_XlsxrXwZQ4DlqbqPg
# IN
# $4.1K - $65.9K per day
# BeyoncéVEVO
# Sep 2nd, 2009
# 9363430998
# UC9zX2xZIJ4cnwRsgBpHGvMg
# US
# $865 - $13.8K per day
# Sony Music India
# Sep 2nd, 2009
# 9178008853
# UC56gTxNs4f9xZ7Pa2i5xNzg
# IN
# $2.6K - $42.2K per day
# LEGO
# Oct 22nd, 2005
# 8928655555
# UCP-Ng5SXUEt0VE-TXqRdL6g
# FR
# $1.1K - $16.9K per day
# JuegaGerman
# May 19th, 2013
# 8826923994
# UCYiGq8XF7YQD00x7wAd62Zg
# CL
# $1.4K - $22.9K per day
# Trap Nation
# Sep 23rd, 2012
# 8793730997
# UCa10nxShhzNrCE1o2ZOPztg
# US
# $1.4K - $23K per day
# Blu Toys Club Surprise
# Dec 23rd, 2010
# 8763632447
# UC7nGdI1YVbdj0lBqEeg8KxQ
# US
# $255 - $4.1K per day
# IGN
# Sep 19th, 2006
# 8704766636
# UCKy1dAqELo0zrOtPkf0eTMw
# US
# $1K - $16.7K per day
# OneDirectionVEVO
# Dec 4th, 2010
# 8595723447
# UCbW18JZRgko_mOGm5er8Yzg
# GB
# $466 - $7.5K per day
# Wave Music
# Dec 20th, 2011
# 564853775
# UCbuK8xxu2P_sqoMnDsoBrrg
# US
# $318 - $5.1K per day
